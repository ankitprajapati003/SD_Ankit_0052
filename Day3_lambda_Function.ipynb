# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitprajapati003/SD_Ankit_0052/blob/main/Day3_lambda_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 3
p = 2

# %%
def test(n,p):
  return n**p

# %%
test(3,4)
# Out:
# 81

# %%
a = lambda n, p:n**p

# %%
a(5,2)
# Out:
# 25

# %%
add = lambda x,y,z,c : x+y+z+c

# %%
add(4,5,6,7)
# Out:
# 22

# %%
c_to_f =lambda c :(9/5)*c +32

# %%
c_to_f(45)
# Out:
# 113.0

# %%
f_to_c =lambda f :((f-32)*5)/9

# %%
f_to_c(56)
# Out:
# 13.333333333333334

# %%
finding_max = lambda x,y: x if x>y else y

# %%
finding_max(8,10)
# Out:
# 10

# %%
finding_min = lambda x,y: x if x<y else y

# %%
finding_min(4,3)
# Out:
# 3

# %%
s = "ankit_prajapti"

# %%
find_len =lambda s : len(s)

# %%
find_len(s)
# Out:
# 14

# %%
find_min = lambda x,y,z : x if (x<y)and(x,z) else (y if (y<x)and(y<z) else z)

# %%
find_min(5,6,8)
# Out:
# 5

# %%
l =[ 2,3,4,5,6,7]

# %%
def test(l):
  l1=[]
  for i in l :
    l1.append(i**2)
  return l1

# %%
test(l)
# Out:
# [4, 9, 16, 25, 36, 49]

# %%
def sq(x):
  return x**2

# %%
list(map(sq,l))
# Out:
# [4, 9, 16, 25, 36, 49]

# %%
l
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
list(map(lambda x : x**2,l))
# Out:
# [4, 9, 16, 25, 36, 49]

# %%
l1= [2,3,4,5,6,7,8,9,8]
l2 =[23,4,5,6,7,8,9,4,0]
list(map(lambda x,y :x+y, l1,l2))
# Out:
# [25, 7, 9, 11, 13, 15, 17, 13, 8]

# %%
def add(x,y):
  return x*y

# %%
list(map(add,l1,l2))
# Out:
# [46, 12, 20, 30, 42, 56, 72, 36, 0]

# %%
s = "ankit prajapati"
list(map(lambda s : s.upper(),s))
# Out:
# ['A', 'N', 'K', 'I', 'T', ' ', 'P', 'R', 'A', 'J', 'A', 'P', 'A', 'T', 'I']

# %%
from functools import reduce

# %%
l = [2,3,4,5,6,7,8,9]

# %%
reduce(lambda x,y : x+y,l)
# Out:
# 44

# %%
reduce(lambda x,y,z : x+y+z,l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9407/2669847218.py in <cell line: 0>()
# ----> 1 reduce(lambda x,y,z : x+y+z,l)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
reduce(lambda x,y : x+y,[1])
# Out:
# 1

# %%
reduce(lambda x,y : x*y,l)
# Out:
# 362880

# %%
reduce(lambda x,y : x if x>y else y,l)
# Out:
# 9
