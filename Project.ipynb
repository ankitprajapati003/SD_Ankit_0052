# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitprajapati003/SD_Ankit_0052/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = input("enter student name: ")

subject_name1 =input("enter first subject name: ")
marks1 = int(input("enter  subject marks:"))

subject_name2 =input("enter second subject name: ")
marks2 = int(input("enter subject marks:"))

subject_name3 =input("enter third subject name: ")
marks3 = int(input("enter subject marks:"))

subject_name4 =input("enter fourth subject name: ")
marks4 = int(input("enter subject marks:"))

subject_name5 =input("enter fifth subject name: ")
marks5 = int(input("enter subject marks:"))

total_marks = marks1 + marks2 + marks3 + marks4 + marks5
print("total Marks", total_marks)
percentage = (total_marks/500)*100
print( student_name , "got this percentage", percentage )

if percentage>= 90:
  print("Grade A+")
elif percentage>= 80:
  print("Grade B")
elif percentage >= 70:
  print("Grade C")
elif percentage >= 60:
  print("Grade D")
elif percentage >= 50:
  print("Grade E")
else:
  print("Grade F")


print( student_name , "got this percentage", percentage )
# Out:
# enter student name: daaad
# enter first subject name: fdf
# enter  subject marks:56
# enter second subject name: dfgf
# enter subject marks:78
# enter third subject name: gfh
# enter subject marks:89
# enter fourth subject name: dfgd
# enter subject marks:89
# enter fifth subject name: ygjh
# enter subject marks:90
# total Marks 402
# Grade B
# daaad got this percentage 80.4 and got this grade
