# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitprajapati003/SD_Ankit_0052/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def test1():
   pass

# %%
def test1():
  print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
test1() + "ankit"

# %%
def test2():
  return "this is my first function call "

# %%
test2() + " ankit"
# Out:
# 'this is my first function call ankit'

# %%
def test3():
  return "sudh",23,453,45.6,[23,4,2,]

# %%
test3()
# Out:
# ('sudh', 23, 453, 45.6, [23, 4, 2])

# %%
a,b,c,d,e =test3()

# %%
a
# Out:
# 'sudh'

# %%
def test4():
  u = 5+6/7
  return u

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d = a+b/c
  return d

# %%
test5(2,5,7)
# Out:
# 2.7142857142857144

# %%
def test6(a,b):
 return a+b

# %%
test6(8,987.09 )
# Out:
# 995.09

# %%
test6("sudh"," kumar")
# Out:
# 'sudh kumar'

# %%
test6((1,2,3,4,5),(4,5,6))
# Out:
# (1, 2, 3, 4, 5, 4, 5, 6)

# %%
l = [1,2,3,4,"ankit", "anmol",[1,2,3,4,5,6,7,8]]

# %%
l1 = []
for i in l :
  if type(i) == int or type(i) == float:
    l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l
# Out:
# [1, 2, 3, 4, 'ankit', 'anmol', [1, 2, 3, 4, 5, 6, 7, 8]]

# %%
def test8(a):
  l =[]
  for i in a:
    if type(i) == list:
      for j in i :
        l.append(j)
    else:
      if type(i) == int or type(i) == float:
        l.append(i)
  return l

# %%
l
# Out:
# [1, 2, 3, 4, 'ankit', 'anmol', [1, 2, 3, 4, 5, 6, 7, 8]]

# %%
a
# Out:
# 'sudh'

# %%
i
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
num1 = int(input("enter the first no: "))
num2 = int(input("enter the second no:"))
ch = input("enter the operator : ")
def  calci(num1,num2,ch):
  result=0
if ch == '+':
  result= num1+num2
elif ch == '-':
  result = num1-num2
elif ch == '*':
  result = num1*num2
elif ch == '/':
  result = num1/num2
else:
  print("invalid operator")
print(num1,ch,num2,":",result)
# Out:
# enter the first no: 798
# enter the second no:8776
# enter the operator : *
# 798 * 8776 : 7003248

# %%
def add(a,b):
  return a+b
def sub(a,b):
  return a-b
def mul(a,b):
  return a*b
def div(a,b):
  return a/b

# %%
add(5,78 )
# Out:
# 83

# %%
print("welcome to ATM")
pin = 2004
balance = 10000
inputpin = int(input("enter the pin: "))
if inputpin == pin:
  print("1.check balance")
  print("2.withdraw")
  print("3.deposit")
  print("4.exit")

  choice = int(input("enter your choice"))
  if choice == 1:
    print("your balance is",balance)
  elif choice == 2:
    withdraw = int(input("enter the amount to withdraw"))
    if withdraw > balance:
      print("insufficient balance")
    else:
      balance = balance - withdraw
      print("withdraw successfull")
      print("your balance is",balance)
  elif choice == 3:
    depoist = int(input("enter the amount to depoist"))
    balance = balance + depoist
    print("your current balance ", balance )
  elif choice == 4:
    print("thank you for using ATM")
  else:
    print("invalid choice")
else:
  print("invalid pin")
# Out:
# welcome to ATM
# enter the pin2004
# 1.check balance
# 2.withdraw
# 3.deposit
# 4.exit
# enter your choice3
# enter the amount to depoist78909
# your current balance  88909

# %%
def test_fib(n):
   a,b = 0,1
   while True:
    yield a
   a,b = b , a+b

# %%
s= "ankit"

# %%
for i in s:
  print(i)
# Out:
# a
# n
# k
# i
# t
